# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
#  YOUR CODE GOES HERE
application_df=application_df.drop(columns=['EIN','NAME'])

# %%
# Determine the number of unique values in each column.
#  YOUR CODE GOES HERE
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
#  YOUR CODE GOES HERE
application_type=application_df['APPLICATION_TYPE'].value_counts()
application_type
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
#  YOUR CODE GOES HERE
application_types_replace=application_type[application_type < 200].index.tolist()
# Replace in dataframe
for app in application_types_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
#  YOUR CODE GOES HERE
classification=application_df['CLASSIFICATION'].value_counts()
classification
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
#  YOUR CODE GOES HERE
classification[classification>1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
#  YOUR CODE GOES HERE
classifications_to_replace=classification[classification<1000].index.tolist()
# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
#  YOUR CODE GOES HERE
X=pd.get_dummies(application_df)
X
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0           1      5000              1                       0
# 1           1    108590              1                       0
# 2           1      5000              0                       0
# 3           1      6692              1                       0
# 4           1    142590              1                       0
# ...       ...       ...            ...                     ...
# 34294       1      5000              0                       0
# 34295       1      5000              0                       0
# 34296       1      5000              0                       0
# 34297       1      5000              1                       0
# 34298       1  36500179              0                       0
#
#        APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                         1                     0                    0
# 1                         0                     0                    1
# 2                         0                     0                    0
# 3                         0                     0                    1
# 4                         0                     0                    1
# ...                     ...                   ...                  ...
# 34294                     0                     0                    0
# 34295                     0                     0                    0
# 34296                     0                     0                    1
# 34297                     0                     0                    0
# 34298                     0                     0                    1
#
#        APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 0                        0                    0                    0  ...
# 1                        0                    0                    0  ...
# 2                        0                    1                    0  ...
# 3                        0                    0                    0  ...
# 4                        0                    0                    0  ...
# ...                    ...                  ...                  ...  ...
# 34294                    1                    0                    0  ...
# 34295                    1                    0                    0  ...
# 34296                    0                    0                    0  ...
# 34297                    0                    1                    0  ...
# 34298                    0                    0                    0  ...
#
#        INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0                      0                       0                         0
# 1                      1                       0                         0
# 2                      0                       0                         0
# 3                      0                       1                         0
# 4                      0                       0                         1
# ...                  ...                     ...                       ...
# 34294                  0                       0                         0
# 34295                  0                       0                         0
# 34296                  0                       0                         0
# 34297                  0                       0                         0
# 34298                  0                       0                         0
#
#        INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0                       0                 0                       0
# 1                       0                 0                       0
# 2                       0                 0                       0
# 3                       0                 0                       0
# 4                       0                 0                       0
# ...                   ...               ...                     ...
# 34294                   0                 0                       0
# 34295                   0                 0                       0
# 34296                   0                 0                       0
# 34297                   0                 0                       0
# 34298                   0                 1                       0
#
#        INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0                    0                  0                         1
# 1                    0                  0                         1
# 2                    0                  0                         1
# 3                    0                  0                         1
# 4                    0                  0                         1
# ...                ...                ...                       ...
# 34294                0                  0                         1
# 34295                0                  0                         1
# 34296                0                  0                         1
# 34297                0                  0                         1
# 34298                0                  0                         1
#
#        SPECIAL_CONSIDERATIONS_Y
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0
# ...                         ...
# 34294                         0
# 34295                         0
# 34296                         0
# 34297                         0
# 34298                         0
#
# [34299 rows x 44 columns]

# %%
# Split our preprocessed data into our features and target arrays
#  YOUR CODE GOES HERE
y=X['IS_SUCCESSFUL']
X = X.drop(columns=['IS_SUCCESSFUL'])
X_train, X_test, y_train, y_test = train_test_split(X, y,random_state=1)# Split the preprocessed data into a training and testing dataset
#  YOUR CODE GOES HERE

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE

nn = tf.keras.models.Sequential()

number_input = 43
# First hidden layer
#  YOUR CODE GOES HERE
layer1=80
nn.add(tf.keras.layers.Dense(units=layer1, input_dim=number_input, activation="relu"))
# Second hidden layer
#  YOUR CODE GOES HERE
layer2=50
nn.add(tf.keras.layers.Dense(units=layer2, activation="relu"))
# Output layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))
# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                3520
#
#  dense_1 (Dense)             (None, 50)                4050
#
#  dense_2 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 7621 (29.77 KB)
# Trainable params: 7621 (29.77 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
#  YOUR CODE GOES HERE
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
#  YOUR CODE GOES HERE
fit_model = nn.fit(X_train_scaled, y_train, epochs=200)
# Out:
# Epoch 1/200
# 804/804 [==============================] - 1s 608us/step - loss: 0.5709 - accuracy: 0.7199
# Epoch 2/200
# 804/804 [==============================] - 1s 633us/step - loss: 0.5561 - accuracy: 0.7274
# Epoch 3/200
# 804/804 [==============================] - 0s 608us/step - loss: 0.5527 - accuracy: 0.7303
# Epoch 4/200
# 804/804 [==============================] - 0s 609us/step - loss: 0.5509 - accuracy: 0.7320
# Epoch 5/200
# 804/804 [==============================] - 0s 604us/step - loss: 0.5491 - accuracy: 0.7313
# Epoch 6/200
# 804/804 [==============================] - 0s 600us/step - loss: 0.5489 - accuracy: 0.7322
# Epoch 7/200
# 804/804 [==============================] - 1s 668us/step - loss: 0.5477 - accuracy: 0.7315
# Epoch 8/200
# 804/804 [==============================] - 0s 613us/step - loss: 0.5470 - accuracy: 0.7334
# Epoch 9/200
# 804/804 [==============================] - 1s 646us/step - loss: 0.5460 - accuracy: 0.7360
# Epoch 10/200
# 804/804 [==============================] - 0s 587us/step - loss: 0.5460 - accuracy: 0.7343
# Epoch 11/200
# 804/804 [==============================] - 0s 610us/step - loss: 0.5452 - accuracy: 0.7346
# Epoch 12/200
# 804/804 [==============================] - 0s 613us/step - loss: 0.5450 - accuracy: 0.7338
# Epoch 13/200
# 804/804 [==============================] - 0s 598us/step - loss: 0.5445 - accuracy: 0.7343
# Epoch 14/200
# 804/804 [==============================] - 1s 635us/step - loss: 0.5448 - accuracy: 0.7353
# Epoch 15/200
# 804/804 [==============================] - 0s 593us/step - loss: 0.5439 - accuracy: 0.7361
# Epoch 16/200
# 804/804 [==============================] - 0s 586us/step - loss: 0.5439 - accuracy: 0.7358
# Epoch 17/200
# 804/804 [==============================] - 0s 596us/step - loss: 0.5435 - accuracy: 0.7350
# Epoch 18/200
# 804/804 [==============================] - 0s 591us/step - loss: 0.5433 - accuracy: 0.7353
# Epoch 19/200
# 804/804 [==============================] - 0s 610us/step - loss: 0.5427 - accuracy: 0.7371
# Epoch 20/200
# 804/804 [==============================] - 0s 593us/step - loss: 0.5428 - accuracy: 0.7367
# Epoch 21/200
# 804/804 [==============================] - 0s 592us/step - loss: 0.5425 - accuracy: 0.7371
# Epoch 22/200
# 804/804 [==============================] - 0s 587us/step - loss: 0.5421 - accuracy: 0.7361
# Epoch 23/200
# 804/804 [==============================] - 0s 591us/step - loss: 0.5418 - accuracy: 0.7364
# Epoch 24/200
# 804/804 [==============================] - 1s 625us/step - loss: 0.5414 - accuracy: 0.7357
# Epoch 25/200
# 804/804 [==============================] - 0s 592us/step - loss: 0.5415 - accuracy: 0.7375
# Epoch 26/200
# 804/804 [==============================] - 0s 585us/step - loss: 0.
step - loss: 0.5323 - accuracy: 0.7414
# Epoch 200/200
# 804/804 [==============================] - 0s 597us/step - loss: 0.5319 - accuracy: 0.7410

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5712 - accuracy: 0.7277 - 207ms/epoch - 774us/step
# Loss: 0.5712137222290039, Accuracy: 0.7276967763900757

# %%
# Export our model to HDF5 file
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/jeanjin/Desktop/DSBC/21/deep-learning-challenge/Starter_Code.ipynb Cell 18 line 2
#       <a href='vscode-notebook-cell:/Users/jeanjin/Desktop/DSBC/21/deep-learning-challenge/Starter_Code.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> # Export our model to HDF5 file
# ----> <a href='vscode-notebook-cell:/Users/jeanjin/Desktop/DSBC/21/deep-learning-challenge/Starter_Code.ipynb#X30sZmlsZQ%3D%3D?line=1'>2</a> model_accuracy.save("AlphabetSoupCharity.h5")
#
# AttributeError: 'float' object has no attribute 'save'

# %%
import keras_tuner as kt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
def build_model(hp):
    nn_model = tf.keras.models.Sequential()

    # Allow kerastuner to decide which activation function to use in hidden layers
    activation = hp.Choice('activation',['relu','tanh','sigmoid'])
    
    # Allow kerastuner to decide number of neurons in first layer
    nn_model.add(tf.keras.layers.Dense(units=hp.Int('first_units',
        min_value=1,
        max_value=100,
        step=20), activation=activation, input_dim=43))

    # Allow kerastuner to decide number of hidden layers and neurons in hidden layers
    for i in range(hp.Int('num_layers', 1, 6)):
        nn_model.add(tf.keras.layers.Dense(units=hp.Int('units_' + str(i),
            min_value=1,
            max_value=100,
            step=20),
            activation=activation))
    
    nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

    # Compile the model
    nn_model.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy"])
    
    return nn_model

# %%
tuner = kt.Hyperband(
    build_model,
    objective='val_accuracy',
    max_epochs=100,
    hyperband_iterations=2)
# Out:
# Reloading Tuner from ./untitled_project/tuner0.json

# %%
tuner.search(X_train_scaled, y_train, epochs=100, validation_data=(X_test_scaled, y_test))
# Out:
# Trial 133 Complete [00h 00m 08s]
# val_accuracy: 0.7329446077346802
#
# Best val_accuracy So Far: 0.7337609529495239
# Total elapsed time: 00h 11m 31s
#
# Search: Running Trial #134
#
# Value             |Best Value So Far |Hyperparameter
# sigmoid           |sigmoid           |activation
# 61                |21                |first_units
# 4                 |5                 |num_layers
# 21                |41                |units_0
# 1                 |21                |units_1
# 21                |21                |units_2
# 41                |41                |units_3
# 21                |1                 |units_4
# 1                 |81                |units_5
# 12                |12                |tuner/epochs
# 4                 |4                 |tuner/initial_epoch
# 4                 |4                 |tuner/bracket
# 2                 |2                 |tuner/round
# 0116              |0100              |tuner/trial_id
#
# Epoch 5/12
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5757 - accuracy: 0.7294 - val_loss: 0.5737 - val_accuracy: 0.7314
# Epoch 6/12
# 804/804 [==============================] - 1s 852us/step - loss: 0.5751 - accuracy: 0.7286 - val_loss: 0.5734 - val_accuracy: 0.7314
# Epoch 7/12
# 804/804 [==============================] - 1s 903us/step - loss: 0.5749 - accuracy: 0.7290 - val_loss: 0.5722 - val_accuracy: 0.7333
# Epoch 8/12
# 804/804 [==============================] - 1s 872us/step - loss: 0.5743 - accuracy: 0.7294 - val_loss: 0.5727 - val_accuracy: 0.7331
# Epoch 9/12
# 749/804 [==========================>...] - ETA: 0s - loss: 0.5743 - accuracy: 0.7301
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/jeanjin/Desktop/DSBC/21/deep-learning-challenge/Starter_Code.ipynb Cell 22 line 1
# ----> <a href='vscode-notebook-cell:/Users/jeanjin/Desktop/DSBC/21/deep-learning-challenge/Starter_Code.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> tuner.search(X_train_scaled, y_train, epochs=100, validation_data=(X_test_scaled, y_test))
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/keras_tuner/src/engine/base_tuner.py:233, in BaseTuner.search(self, *fit_args, **fit_kwargs)
#     230         continue
#     232     self.on_trial_begin(trial)
# --> 233     self._try_run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     234     self.on_trial_end(trial)
#     235 self.on_search_end()
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/keras_tuner/src/engine/base_tuner.py:273, in BaseTuner._try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     271 def _try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
#     272     try:
# --> 273         self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     274         trial.status = trial_module.TrialStatus.COMPLETED
#     275         return
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/keras_tuner/src/engine/base_tuner.py:238, in BaseTuner._run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     237 def _run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
# --> 238     results = self.run_trial(trial, *fit_args, **fit_kwargs)
#     239     if self.oracle.get_trial(trial.trial_id).metrics.exists(
#     240         self.oracle.objective.name
#     241     ):
#     242         # The oracle is updated by calling `self.oracle.update_trial()` in
#     243         # `Tuner.run_trial()`. For backward compatibility, we support this
#     244         # use case. No further action needed in this case.
#     245         warnings.warn(
#     246             "The use case of calling "
#     247             "`self.oracle.update_trial(trial_id, metrics)` "
#    (...)
#     253             stacklevel=2,
#     254         )
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/keras_tuner/src/tuners/hyperband.py:427, in Hyperband.run_trial(self, trial, *fit_args, **fit_kwargs)
#     425     fit_kwargs["epochs"] = hp.values["tuner/epochs"]
#     426     fit_kwargs["initial_epoch"] = hp.values["tuner/initial_epoch"]
# --> 427 return super().run_trial(trial, *fit_args, **fit_kwargs)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/keras_tuner/src/engine/tuner.py:314, in Tuner.run_trial(self, trial, *args, **kwargs)
#     312     callbacks.append(model_checkpoint)
#     313     copied_kwargs["callbacks"] = callbacks
# --> 314     obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#     316     histories.append(obj_value)
#     317 return histories
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/keras_tuner/src/engine/tuner.py:233, in Tuner._build_and_fit_model(self, trial, *args, **kwargs)
#     231 hp = trial.hyperparameters
#     232 model = self._try_build(hp)
# --> 233 results = self.hypermodel.fit(hp, model, *args, **kwargs)
#     235 # Save the build config for model loading later.
#     236 if backend.config.multi_backend():
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/keras_tuner/src/engine/hypermodel.py:149, in HyperModel.fit(self, hp, model, *args, **kwargs)
#     125 def fit(self, hp, model, *args, **kwargs):
#     126     """Train the model.
#     127
#     128     Args:
#    (...)
#     147         If return a float, it should be the `objective` value.
#     148     """
# --> 149     return model.fit(*args, **kwargs)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/keras/src/engine/training.py:1856, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1840 if getattr(self, "_eval_data_handler", None) is None:
#    1841     self._eval_data_handler = data_adapter.get_data_handler(
#    1842         x=val_x,
#    1843         y=val_y,
#    (...)
#    1854         pss_evaluation_shards=self._pss_evaluation_shards,
#    1855     )
# -> 1856 val_logs = self.evaluate(
#    1857     x=val_x,
#    1858     y=val_y,
#    1859     sample_weight=val_sample_weight,
#    1860     batch_size=validation_batch_size or batch_size,
#    1861     steps=validation_steps,
#    1862     callbacks=callbacks,
#    1863     max_queue_size=max_queue_size,
#    1864     workers=workers,
#    1865     use_multiprocessing=use_multiprocessing,
#    1866     return_dict=True,
#    1867     _use_cached_eval_dataset=True,
#    1868 )
#    1869 val_logs = {
#    1870     "val_" + name: val for name, val in val_logs.items()
#    1871 }
#    1872 epoch_logs.update(val_logs)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/keras/src/engine/training.py:2291, in Model.evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    2289 self.reset_metrics()
#    2290 with data_handler.catch_stop_iteration():
# -> 2291     for step in data_handler.steps():
#    2292         with tf.profiler.experimental.Trace(
#    2293             "test", step_num=step, _r=1
#    2294         ):
#    2295             callbacks.on_test_batch_begin(step)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/keras/src/engine/data_adapter.py:1411, in DataHandler.steps(self)
#    1409 if self._insufficient_data:  # Set by `catch_stop_iteration`.
#    1410     break
# -> 1411 original_spe = self._steps_per_execution.numpy().item()
#    1412 can_run_full_execution = (
#    1413     original_spe == 1
#    1414     or self._inferred_steps is None
#    1415     or self._inferred_steps - self._current_step >= original_spe
#    1416 )
#    1418 if can_run_full_execution:
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/tensorflow/python/ops/resource_variable_ops.py:689, in BaseResourceVariable.numpy(self)
#     687 def numpy(self):
#     688   if context.executing_eagerly():
# --> 689     return self.read_value().numpy()
#     690   raise NotImplementedError(
#     691       "numpy() is only available when eager execution is enabled.")
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/tensorflow/python/ops/resource_variable_ops.py:842, in BaseResourceVariable.read_value(self)
#     839   value = self._read_variable_op()
#     840 # Return an identity so it can get placed on whatever device the context
#     841 # specifies instead of the device where the variable is.
# --> 842 return array_ops.identity(value)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/tensorflow/python/ops/weak_tensor_ops.py:88, in weak_tensor_unary_op_wrapper.<locals>.wrapper(*args, **kwargs)
#      86 def wrapper(*args, **kwargs):
#      87   if not ops.is_auto_dtype_conversion_enabled():
# ---> 88     return op(*args, **kwargs)
#      89   bound_arguments = signature.bind(*args, **kwargs)
#      90   bound_arguments.apply_defaults()
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/tensorflow/python/ops/array_ops.py:311, in identity(input, name)
#     307   return nest.map_structure(identity, input, expand_composites=True)
#     308 if context.executing_eagerly() and not hasattr(input, "graph"):
#     309   # Make sure we get an input with handle data attached from resource
#     310   # variables. Variables have correct handle data when graph building.
# --> 311   input = ops.convert_to_tensor(input)
#     312 ret = gen_array_ops.identity(input, name=name)
#     313 # Propagate handle data for happier shape inference for resource variables.
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/tensorflow/python/profiler/trace.py:183, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     181   with Trace(trace_name, **trace_kwargs):
#     182     return func(*args, **kwargs)
# --> 183 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/tensorflow/python/framework/ops.py:696, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#     694 # TODO(b/142518781): Fix all call-sites and remove redundant arg
#     695 preferred_dtype = preferred_dtype or dtype_hint
# --> 696 return tensor_conversion_registry.convert(
#     697     value, dtype, name, as_ref, preferred_dtype, accepted_result_types
#     698 )
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/tensorflow/python/framework/tensor_conversion_registry.py:209, in convert(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     207 overload = getattr(value, "__tf_tensor__", None)
#     208 if overload is not None:
# --> 209   return overload(dtype, name)  #  pylint: disable=not-callable
#     211 for base_type, conversion_func in get(type(value)):
#     212   # If dtype is None but preferred_dtype is not None, we try to
#     213   # cast to preferred_dtype first.
#     214   ret = None
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/tensorflow/python/framework/ops.py:582, in _EagerTensorBase.__tf_tensor__(self, dtype, name)
#     579 def __tf_tensor__(
#     580     self, dtype: Optional[dtypes.DType] = None, name: Optional[str] = None
#     581     ) -> tensor_lib.Tensor:
# --> 582   if not context.executing_eagerly():
#     583     graph = get_default_graph()
#     584     if not graph.building_function:
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/tensorflow/python/eager/context.py:2293, in executing_eagerly()
#    2289   """Returns the operation seed generated based on global seed."""
#    2290   return context()._internal_operation_seed()  # pylint: disable=protected-access
# -> 2293 @tf_export("executing_eagerly", v1=[])
#    2294 def executing_eagerly():
#    2295   """Checks whether the current thread has eager execution enabled.
#    2296
#    2297   Eager execution is enabled by default and this API returns `True`
#    (...)
#    2345     `True` if the current thread has eager execution enabled.
#    2346   """
#    2347   ctx = context_safe()
#
# KeyboardInterrupt:

# %%
best_model = tuner.get_best_models(num_models=1)[0]
best_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 21)                924
#
#  dense_1 (Dense)             (None, 41)                902
#
#  dense_2 (Dense)             (None, 21)                882
#
#  dense_3 (Dense)             (None, 21)                462
#
#  dense_4 (Dense)             (None, 41)                902
#
#  dense_5 (Dense)             (None, 1)                 42
#
#  dense_6 (Dense)             (None, 1)                 2
#
# =================================================================
# Total params: 4116 (16.08 KB)
# Trainable params: 4116 (16.08 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
best_model = tuner.get_best_models(1)[0]
model_loss, model_accuracy = best_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.iter
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.decay
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.learning_rate
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.iter
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.decay
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.learning_rate
# 268/268 - 0s - loss: 0.5779 - accuracy: 0.7338 - 244ms/epoch - 912us/step
# Loss: 0.5778540968894958, Accuracy: 0.7337609529495239

# %%
nn.save("AlphabetSoupCharity.h5")
# Out:
# /Users/jeanjin/anaconda3/envs/dev/lib/python3.10/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
